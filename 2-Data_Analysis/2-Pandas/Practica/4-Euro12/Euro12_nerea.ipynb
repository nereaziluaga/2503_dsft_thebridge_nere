# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"

euro12 = pd.read_csv(url)
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Team                        16 non-null     object
#  1   Goals                       16 non-null     int64
#  2   Shots on target             16 non-null     int64
#  3   Shots off target            16 non-null     int64
#  4   Shooting Accuracy           16 non-null     object
#  5   % Goals-to-shots            16 non-null     object
#  6   Total shots (inc. Blocked)  16 non-null     int64
#  7   Hit Woodwork                16 non-null     int64
#  8   Penalty goals               16 non-null     int64
#  9   Penalties not scored        16 non-null     int64
#  10  Headed goals                16 non-null     int64
#  11  Passes                      16 non-null     int64
#  12  Passes completed            16 non-null     int64
# ...

# %%
euro12.describe()
# Out:
#            Goals  Shots on target  Shots off target  \
# count  16.000000        16.000000         16.000000
# mean    4.750000        17.125000         24.937500
# std     2.886751        10.582218         10.680005
# min     1.000000         7.000000         10.000000
# 25%     2.750000         9.750000         18.000000
# 50%     4.500000        13.000000         23.500000
# 75%     5.250000        22.000000         32.250000
# max    12.000000        42.000000         45.000000
#
#        Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# count                   16.000000     16.000000      16.000000
# mean                    54.937500      1.250000       0.187500
# std                     26.065223      1.612452       0.403113
# min                     27.000000      0.000000       0.000000
# 25%                     36.500000      0.000000       0.000000
# 50%                     44.000000      1.000000       0.000000
# ...

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro12 ["Goals"]
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12[["Team", "Goals"]].sort_values("Goals", ascending=False)
# Out:
#                    Team  Goals
# 13                Spain     12
# 5               Germany     10
# 10             Portugal      6
# 7                 Italy      6
# 14               Sweden      5
# 12               Russia      5
# 3               England      5
# 6                Greece      5
# 1        Czech Republic      4
# 0               Croatia      4
# 2               Denmark      4
# 4                France      3
# 8           Netherlands      2
# 9                Poland      2
# 15              Ukraine      2
# 11  Republic of Ireland      1

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
participants= len(euro12["Team"].unique())
print (participants)
# Out:
# 16

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
euro12.shape
# Out:
# (16, 35)

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
discipline=euro12[["Team","Yellow Cards","Red Cards"]]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
euro12[["Team", "Red Cards"]].sort_values(by="Red Cards")
# Out:
#                    Team  Red Cards
# 0               Croatia          0
# 1        Czech Republic          0
# 2               Denmark          0
# 3               England          0
# 4                France          0
# 5               Germany          0
# 7                 Italy          0
# 8           Netherlands          0
# 14               Sweden          0
# 10             Portugal          0
# 13                Spain          0
# 12               Russia          0
# 15              Ukraine          0
# 6                Greece          1
# 11  Republic of Ireland          1
# 9                Poland          1

# %%
euro12[["Team", "Yellow Cards"]].sort_values(by="Yellow Cards")
# Out:
#                    Team  Yellow Cards
# 2               Denmark             4
# 5               Germany             4
# 3               England             5
# 8           Netherlands             5
# 15              Ukraine             5
# 12               Russia             6
# 11  Republic of Ireland             6
# 4                France             6
# 14               Sweden             7
# 9                Poland             7
# 1        Czech Republic             7
# 0               Croatia             9
# 6                Greece             9
# 13                Spain            11
# 10             Portugal            12
# 7                 Italy            16

# %%
euro12.sort_values(["Red Cards", "Yellow Cards"],ascending=[False,False])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 6                Greece      5                8                18
# 9                Poland      2               15                23
# 11  Republic of Ireland      1                7                12
# 7                 Italy      6               34                45
# 10             Portugal      6               22                42
# 13                Spain     12               42                33
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 14               Sweden      5               17                19
# 4                France      3               22                24
# 12               Russia      5                9                31
# 3               England      5               11                18
# 8           Netherlands      2               12                36
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro12.groupby("Team")["Yellow Cards"].mean()
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %%
euro12["Yellow Cards"].mean().round(1)
# Out:
# np.float64(7.4)

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
mask= euro12["Goals"] > 6
Goleadores=euro12[mask]
Goleadores
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                      0             2    2774              2427
# 13                     0             2    4317              3820
#
#    Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5             87.4%     3761      101        60             35       91
# 13            88.4%     5585       69       106             44      122
#
#     Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %%
euro12.loc[euro12["Goals"]>6"Team"]
# Out:
#   Cell In[20], line 1
#     euro12.loc[euro12["Goals"]>6"Team"]
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
euro12.loc[euro12["Goals"]>6"Team","Goals"]

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
mask=euro12["Team"].str[0]=="G"
equipos_g = euro12[mask]
equipos_g
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  Headed goals  Passes  Passes completed  \
# 5                     0             2    2774              2427
# 6                     1             0    1187               911
#
#   Passing Accuracy  Touches  Crosses  Dribbles  Corners Taken  Tackles  \
# 5            87.4%     3761      101        60             35       91
# 6            76.7%     2016       52        53             10       65
#
#    Clearances  Interceptions  Clearances off line  Clean Sheets  Blocks  \
# ...

# %%
euro12[euro12 #probar con uns startswith

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
print(euro12.iloc[:, :7])
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
print(euro12.shape)
print(euro12.iloc[:, :-3])
# Out:
# (16, 35)
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12["Team"].isin(["England", "Italy", "Russia"]), ["Team", "Shooting Accuracy"]]
# cn isin filtro las filas donde dentro de "Team": Inglaterra, Italia y Rusia.
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %%
country_mask = euro12[(euro12["Team"] == "England") | (euro12["Team"] == "Italy") | (euro12["Team"] == "Russia")]
country_mask.set_index("Team")["Shooting Accuracy"]
# Out:
# Team
# England    50.0%
# Italy      43.0%
# Russia     22.5%
# Name: Shooting Accuracy, dtype: object
